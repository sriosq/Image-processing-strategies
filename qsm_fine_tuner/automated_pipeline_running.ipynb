# %% [markdown]
# # <span style="color:#1FCBED"> Calling the automated pipeline code wrappers </span> </br>
# Pipeline mk1: </br>
# - Fieldmappin with ROMEO,
# - BGFR: PDF with SC-optimized parameters with noisy MRsim
# - DI: (CONTINUE TESTING)

# %%
import numpy as np
import nibabel as nib
import importlib

# %%
import automated_pipeline_running
importlib.reload(automated_pipeline_running)
from automated_pipeline_running import bgfr_comp, di_comp, fieldmap_to_chimap_wrapper, signal_to_fm_Hz

# %%
test_params_struct = {
        'general' : {
            'isBET' : '0',
            'isInvert':'0',
            'isRefineBrainMask' : '0'
        },
        'bfr':{
            'method': "PDF",
            'tol': 0.001,
            'iteration': 200,
            'padSize': 34,
            "refine_method" : "None",
            "refine_order" : 4,
            'erode_radius': 0,
            'erode_before_radius': 0}
        }

# %%
test_params_struct['bfr']['method']
# Out:
# 'PDF'

# %%
# Now running the pipelinec

chi003_m2_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\fm_tests\test2_msk_apply\B0.nii"
chi003_m2_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\chi_003_m2_header.mat"
chi003_m2_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\chi_003_m2_sc_msk.nii.gz"
chi003_m2_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\auto_pipeline_running"

chi003_m4_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\4th_3D_meGRE\fm_tests\test2_msk_apply\B0.nii"
chi003_m4_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\4th_3D_meGRE\chi_003_m4_header.mat"
chi003_m4_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\4th_3D_meGRE\chi_003_m4_sc_msk.nii.gz"
chi003_m4_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\4th_3D_meGRE\auto_pipeline_running"

chi003_m6_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\6th_3D_meGRE\fm_tests\test2_msk_apply\B0.nii"
chi003_m6_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\6th_3D_meGRE\chi_003_m6_header.mat"
chi003_m6_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\6th_3D_meGRE\chi_003_m6_sc_msk.nii.gz"
chi003_m6_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\6th_3D_meGRE\auto_pipeline_running"

fieldmap_to_chimap_wrapper(chi003_m2_fieldmap_path, chi003_m2_header_path, chi003_m2_msk_path, 'mk1', chi003_m2_outpath)
fieldmap_to_chimap_wrapper(chi003_m4_fieldmap_path, chi003_m4_header_path, chi003_m4_msk_path, 'mk1', chi003_m4_outpath)
fieldmap_to_chimap_wrapper(chi003_m6_fieldmap_path, chi003_m6_header_path, chi003_m6_msk_path, 'mk1', chi003_m6_outpath)

# %% [markdown]
# ## <span style="color:#aaaa7f"> Chi_003 </span> </br>

# %%
# Automated chi_003_m2 BGFR comp running
chi003_m2_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\fm_tests\test3_bipolar_corr\B0.nii"
chi003_m2_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\chi_003_m2_header.mat"
chi003_m2_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\chi_003_m2_sc_msk_T0000.nii.gz" 
chi003_m2_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images"
chi_003_noise_sd_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\n_std_output\n_std.nii.gz"

bgfr_comp(chi003_m2_fieldmap_path, chi003_m2_header_path, chi003_m2_msk_path, "comp_bgfr", chi003_m2_outpath, chi_003_noise_sd_path)
# Out:
# Beginning BGFR algo comp automated running
# Input algo:  def_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_bgfr\def_pdf/def_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_pdf
# Algo:  PDF
# Output path E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_bgfr\opt_pdf/Sepia already exists, skipping algo: PDF
# Beginning BGFR algo comp automated running
# Input algo:  def_lbv
# Algo:  LBV
# Output path E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_bgfr\def_lbv/Sepia already exists, skipping algo: LBV
# Beginning BGFR algo comp automated running
# Input algo:  opt_lbv
# Algo:  LBV
# ...

# %%
# Automated chi_003_m2 DI comp running
chi003_m2_best_lf_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_bgfr\opt_pdf\Sepia_localfield.nii.gz"
chi003_m2_di_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images"
chi_003_mag_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\chi_003_m2_mag.nii.gz"

di_comp(chi003_m2_best_lf_path, chi003_m2_header_path, chi003_m2_msk_path, "comp_di", chi003_m2_di_outpath, path_to_mag = chi_003_mag_path)
# Out:
# Beginning DI algo comp automated running
# Input algo:  def_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_di\def_tkd/def_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_di\opt_tkd/opt_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  def_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_di\def_iLSQR/def_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_003\qsm_processing\2nd_3D_meGRE\final_w_images\comp_di\opt_iLSQR/opt_iLSQR.png
# ...

# %% [markdown]
# ## <span style="color:#715DC2"> Chi_004 </span> </br>

# %%
# Automated chi_004_m2 BGFR comp running
chi004_m2_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\fm_tests\test3_bipolar\B0.nii"
chi004_m2_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\chi_004_m2_header.mat"
chi004_m2_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\chi_004_m2_sc_msk.nii.gz"
chi_004_noise_sd_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\n_std_output\n_std.nii.gz"

# %%
chi004_m2_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images"

bgfr_comp(chi004_m2_fieldmap_path, chi004_m2_header_path, chi004_m2_msk_path, "comp_bgfr", chi004_m2_outpath, chi_004_noise_sd_path)
# Out:
# Beginning BGFR algo comp automated running
# Input algo:  def_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_bgfr\def_pdf/def_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_bgfr\opt_pdf/opt_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  def_lbv
# Algo:  LBV
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_bgfr\def_lbv/def_lbv.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_lbv
# Algo:  LBV
# ...

# %%
# Automated chi_004_m2 DI comp running
chi004_m2_best_lf_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_bgfr\opt_pdf\Sepia_localfield.nii.gz"
chi004_m2_di_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images"
chi_004_m2_mag_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\chi_004_m2_noGrappaC2_mag.nii.gz"

di_comp(chi004_m2_best_lf_path, chi004_m2_header_path, chi004_m2_msk_path, "comp_di", chi004_m2_di_outpath, path_to_mag=chi_004_m2_mag_path)
# Out:
# Beginning DI algo comp automated running
# Input algo:  def_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_di\def_tkd/def_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_di\opt_tkd/opt_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  def_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_di\def_iLSQR/def_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_004\qsm_processing\m2\final_w_images\comp_di\opt_iLSQR/opt_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# ...

# %% [markdown]
# ## <span style="color:#5DBDC2"> Chi_005 </span> </br>

# %%
# Automated chi_005 BGFR comp running
chi005_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\fm_tests\test3_bipolar_corr\B0.nii"
chi005_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\chi_005_header.mat"
chi005_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\chi_005_sc_msk.nii.gz"
chi005_noise_sd_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\n_std_output\n_std.nii.gz"

# %%
chi005_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images"

bgfr_comp(chi005_fieldmap_path, chi005_header_path, chi005_msk_path, "comp_bgfr", chi005_outpath, chi005_noise_sd_path)
# Out:
# Beginning BGFR algo comp automated running
# Input algo:  def_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_bgfr\def_pdf/def_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_bgfr\opt_pdf/opt_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  def_lbv
# Algo:  LBV
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_bgfr\def_lbv/def_lbv.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_lbv
# Algo:  LBV
# Using noise SD!
# ...

# %%
# Automated chi_005 DI comp running
chi005_best_lf_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_bgfr\opt_pdf\Sepia_localfield.nii.gz"
chi005_di_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images"
chi_005_mag_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\chi_005_mag.nii.gz"

di_comp(chi005_best_lf_path, chi005_header_path, chi005_msk_path, "comp_di", chi005_di_outpath, path_to_mag=chi_005_mag_path)
# Out:
# Beginning DI algo comp automated running
# Input algo:  def_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_di\def_tkd/def_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_di\opt_tkd/opt_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  def_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_di\def_iLSQR/def_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_005\qsm_processing\final_w_images\comp_di\opt_iLSQR/opt_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# ...

# %% [markdown]
# ## <span style="color:#C871E3"> Chi_006 </span> </br>

# %%
# Automated chi_006 BGFR comp running
chi006_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\fm_tests\test2_msk_apply\B0.nii"
chi006_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\chi_006_m3_header.mat"
chi006_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\chi_006_m3_sc_msk.nii.gz"
chi006_noise_sd_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\n_std_output\n_std.nii.gz"

# %%
chi006_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images"

bgfr_comp(chi006_fieldmap_path, chi006_header_path, chi006_msk_path, "comp_bgfr", chi006_outpath, chi006_noise_sd_path)
# Out:
# Beginning BGFR algo comp automated running
# Input algo:  def_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_bgfr\def_pdf/def_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_bgfr\opt_pdf/opt_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  def_lbv
# Algo:  LBV
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_bgfr\def_lbv/def_lbv.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_lbv
# Algo:  LBV
# Using noise SD!
# ...

# %%
# Automated chi_006 DI comp running
chi006_best_lf_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_bgfr\opt_pdf\Sepia_localfield.nii.gz"
chi006_di_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images"
chi_006_mag_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\chi_006_m3_mag.nii.gz"

di_comp(chi006_best_lf_path, chi006_header_path, chi006_msk_path, "comp_di", chi006_di_outpath, path_to_mag = chi_006_mag_path)
# Out:
# Beginning DI algo comp automated running
# Input algo:  def_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_di\def_tkd/def_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_di\opt_tkd/opt_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  def_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_di\def_iLSQR/def_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_006\qsm_processing\final_w_images\comp_di\opt_iLSQR/opt_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# ...

# %% [markdown]
# ## <span style="color:#E371AC"> Chi_007 </span> </br>

# %%
# Automated chi_007 BGFR comp running
chi007_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\fm_tests\test2_msk_apply/B0.nii"
chi007_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\chi_007_m1_header.mat"
chi007_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\chi_007_m1_sc_msk.nii.gz"
chi007_noise_sd_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\n_std_output\n_std.nii.gz"

# %%
chi007_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images"

bgfr_comp(chi007_fieldmap_path, chi007_header_path, chi007_msk_path, "comp_bgfr", chi007_outpath, chi007_noise_sd_path)
# Out:
# Beginning BGFR algo comp automated running
# Input algo:  def_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_bgfr\def_pdf/def_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_bgfr\opt_pdf/opt_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  def_lbv
# Algo:  LBV
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_bgfr\def_lbv/def_lbv.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_lbv
# Algo:  LBV
# Using noise SD!
# ...

# %%
# Automated chi_007 DI comp running
chi007_best_lf_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_bgfr\opt_pdf\Sepia_localfield.nii.gz"
chi007_di_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images"
chi_007_mag_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\chi_007_m1_mag.nii.gz"

di_comp(chi007_best_lf_path, chi007_header_path, chi007_msk_path, "comp_di", chi007_di_outpath, path_to_mag = chi_007_mag_path)
# Out:
# Beginning DI algo comp automated running
# Input algo:  def_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_di\def_tkd/def_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_di\opt_tkd/opt_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  def_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_di\def_iLSQR/def_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_007\qsm_processing\final_w_images\comp_di\opt_iLSQR/opt_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# ...

# %% [markdown]
# ## <span style="color:#E3D071"> Chi_008 </span> </br>

# %%
# Automated chi_008 BGFR comp running
chi008_fieldmap_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\fm_tests\test2_msk_apply\B0.nii"
chi008_header_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\chi_008_header.mat"
chi008_msk_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\chi_008_sc_msk.nii.gz"
chi008_noise_sd_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\n_std_output\n_std.nii.gz"

# %%
chi008_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images"

bgfr_comp(chi008_fieldmap_path, chi008_header_path, chi008_msk_path, "comp_bgfr", chi008_outpath, chi008_noise_sd_path)
# Out:
# Beginning BGFR algo comp automated running
# Input algo:  def_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_bgfr\def_pdf/def_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_pdf
# Algo:  PDF
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_bgfr\opt_pdf/opt_pdf.png
# Beginning BGFR algo comp automated running
# Input algo:  def_lbv
# Algo:  LBV
# Using noise SD!
# Local Field Created! Calculate metrics and update parameters!
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_bgfr\def_lbv/def_lbv.png
# Beginning BGFR algo comp automated running
# Input algo:  opt_lbv
# Algo:  LBV
# Using noise SD!
# ...

# %%
# Automated chi_007 DI comp running
chi008_best_lf_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_bgfr\opt_pdf\Sepia_localfield.nii.gz"
chi008_di_outpath = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images"
chi_008_mag_path = r"E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\chi_008_mag.nii.gz"

di_comp(chi008_best_lf_path, chi008_header_path, chi008_msk_path, "comp_di", chi008_di_outpath, path_to_mag=chi_008_mag_path)
# Out:
# Beginning DI algo comp automated running
# Input algo:  def_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_di\def_tkd/def_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_tkd
# Algo:  TKD
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_di\opt_tkd/opt_tkd.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  def_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_di\def_iLSQR/def_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# Input algo:  opt_iLSQR
# Algo:  iLSQR
# Creating slicewise png save at:  E:\msc_data\sc_qsm\neuropoly_data\chi_008\qsm_processing\final_w_images\comp_di\opt_iLSQR/opt_iLSQR.png
# Chi-map created! Calculate metrics and update parameters!
# ...

# %% [markdown]
# ## <span style="color:#ff3988"> Swiss 7T mk1 </span> </br>

# %%
# All 3 measurements use the same TEs thus have the same header
swiss_7T_TEs_list = [4.55, 8.81, 13.07, 17.33, 21.59]
swiss_7T_header_path = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\swiss_7T_header.mat"

# %%
swiss_7T_m1_mag_path = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fixed_NS_V_S17_mag.nii.gz"
swiss_7T_m1_ph_path =  r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fixed_NS_V_S18_ph.nii.gz"
swiss_7T_m1_fm_path =  r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fieldmap/test1_msk_apply/B0.nii"
swiss_7T_m1_msk_path = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\swiss_7T_mk1_m1_sc_msk.nii.gz"

signal_to_fm_Hz(swiss_7T_m1_mag_path, swiss_7T_m1_ph_path, swiss_7T_TEs_list, swiss_7T_m1_fm_path, msk_path = swiss_7T_m1_msk_path)

swiss_7T_m1_pipeline_outpath = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\auto_pipeline_running"
fieldmap_to_chimap_wrapper(swiss_7T_m1_fm_path, swiss_7T_header_path, swiss_7T_m1_msk_path, 'mk1', swiss_7T_m1_pipeline_outpath)
# Out:
# Local Field Created! Calculate metrics and update parameters!
# Chi map Created! Calculate metrics and update parameters!

# %%
swiss_7T_m2_mag_path = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m2\fixed_NS_V_S19_mag.nii.gz"
swiss_7T_m2_ph_path =  r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m2\fixed_NS_V_S20_ph.nii.gz"
swiss_7T_m2_fm_path =  r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m2\fieldmap/test1_msk_apply/B0.nii"
swiss_7T_m2_msk_path = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m2\swiss_7T_mk1_m2_sc_msk.nii.gz"

signal_to_fm_Hz(swiss_7T_m2_mag_path, swiss_7T_m2_ph_path, swiss_7T_TEs_list, swiss_7T_m2_fm_path, msk_path = swiss_7T_m2_msk_path)

swiss_7T_mk2_pipeline_outpath = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m2\auto_pipeline_running"
fieldmap_to_chimap_wrapper(swiss_7T_m2_fm_path, swiss_7T_header_path, swiss_7T_m2_msk_path, 'mk1', swiss_7T_mk2_pipeline_outpath)
# Out:
# Local Field Created! Calculate metrics and update parameters!
# Chi map Created! Calculate metrics and update parameters!

# %%
swiss_7T_m3_mag_path = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m3\fixed_NS_V_S21_mag.nii.gz"
swiss_7T_m3_ph_path =  r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m3\fixed_NS_V_S22_ph.nii.gz"
swiss_7T_m3_fm_path =  r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m3\fieldmap/test1_msk_apply/B0.nii"
swiss_7T_m3_msk_path = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m3\swiss_7T_mk1_m3_sc_msk.nii.gz"

signal_to_fm_Hz(swiss_7T_m3_mag_path, swiss_7T_m3_ph_path, swiss_7T_TEs_list, swiss_7T_m3_fm_path, msk_path = swiss_7T_m3_msk_path)

swiss_7T_mk3_pipeline_outpath = r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m3\auto_pipeline_running"
fieldmap_to_chimap_wrapper(swiss_7T_m3_fm_path, swiss_7T_header_path, swiss_7T_m3_msk_path, 'mk1', swiss_7T_mk3_pipeline_outpath)
# Out:
# Local Field Created! Calculate metrics and update parameters!
# Chi map Created! Calculate metrics and update parameters!

# %%
# Unmasked FM 
unmmaksed_swiss_7T_m1_fm_path =  r"E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fieldmap/test2_no_msk/B0.nii"
signal_to_fm_Hz(swiss_7T_m1_mag_path, swiss_7T_m1_ph_path, swiss_7T_TEs_list, unmmaksed_swiss_7T_m1_fm_path)
# Out:
# Running ROMEO with command:
# julia c:/romeo/romeo.jl -p E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fixed_NS_V_S18_ph.nii.gz -m E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fixed_NS_V_S17_mag.nii.gz -B -Q -t [4.55, 8.81, 13.07, 17.33, 21.59] -o E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fieldmap/test2_no_msk/B0.nii
# ROMEO completed. Output saved in: E:\msc_data\sc_qsm\swiss_data_7T\QSM_processing\m1\fieldmap/test2_no_msk/B0.nii
