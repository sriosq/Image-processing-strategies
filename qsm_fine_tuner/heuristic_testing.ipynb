# %% [markdown]
# # <span style="color:#55ffff"> Manually creating chi or tissue-field maps and then manually computing RMSE to a GT </span> </br>

# %%
from compute_RMSE import compare_to_gt

# %%
in_chi_map_path = r"E:\msc_data\sc_qsm\final_gauss_sims\August_2025\mrsim_outputs\custom_params\sus_mapping_opt\iter_FANSI\weakH_off\manual_tests\test2\Sepia_Chimap.nii.gz"
chi_dist_gt_data_path = r"E:\msc_data\sc_qsm\final_gauss_sims\August_2025\ground_truth_data\gt_ref_avg_sc_gauss_chi_dist_crop.nii.gz"

gm_mask_path = r"E:\msc_data\sc_qsm\final_gauss_sims/masks/sc_gm_crop.nii.gz"
wm_mask_path = r"E:\msc_data\sc_qsm\final_gauss_sims/masks/sc_wm_crop.nii.gz"

compare_to_gt(in_chi_map_path, chi_dist_gt_data_path, gm_mask_path, wm_mask_path)
# Out:
# GM Mean Diff: -0.0011277373218597547, GM Std Diff: 0.00920365780665379, GM RMSE: 0.009272492032301492
# WM Mean Diff: -0.003651113911798869, WM Std Diff: 0.006929490470483457, WM RMSE: 0.007832526474736761
# Total RMSE (GM + WM): 0.01710501850703825
# np.float64(0.01710501850703825)
